# %%
import pandas as pd

# %%
# Out:
# [                                                   0   1        2   3   4   5  \
#  0                                                NaN NaN  Monthly NaN NaN NaN
#  1  Home  | FAQs  Unemployment Rate in India βeta ... NaN      NaN NaN NaN NaN
#
#          6   7
#  0  Weekly NaN
#  1     NaN NaN  ,
#                                                     0   1        2   3   4   5  \
#  0                                                NaN NaN  Monthly NaN NaN NaN
#  1  Home  | FAQs  Unemployment Rate in India βeta ... NaN      NaN NaN NaN NaN
#  2  Monthly  Weekly  var CHT_5f4a44ee9a1f8= CMIEOB... NaN      NaN NaN NaN NaN
#  3  .cfoot { font-family:"Times New Roman",Times,s... NaN      NaN NaN NaN NaN
#
#          6   7
#  0  Weekly NaN
#  1     NaN NaN
#  2     NaN NaN
#  3     NaN NaN  ,
#                                                     0
#  0                                       Home  | FAQs
#  1                    Unemployment Rate in India βeta
# ...

# %%
t
# Out:
# list

# %%
df[6]
# Out:
#                                                    0   1
# 0  Home | Motivation | Description | Methodology ... NaN
